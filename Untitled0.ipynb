# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelo2929/projeto-curso-git/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from pandas_datareader import  dados as wb

# %%
import matplotlib.pyplot as plt

# %%
# !pip install yfinance

# %%
import yfinance as yf

PG = yf.download('PG', start='1995-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
PG.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1995-01-03  15.46875  15.62500  15.43750  15.59375   7.674552  3318400
# 1995-01-04  15.53125  15.65625  15.31250  15.46875   7.613035  2218800
# 1995-01-05  15.37500  15.43750  15.21875  15.25000   7.505374  2319600
# 1995-01-06  15.15625  15.40625  15.15625  15.28125   7.520754  3438000
# 1995-01-09  15.34375  15.40625  15.18750  15.21875   7.489995  1795200

# %%
PG.tail()
# Out:
#                   Open        High         Low       Close   Adj Close   Volume
# Date
# 2023-09-25  151.179993  151.279999  150.020004  150.660004  150.660004  5527000
# 2023-09-26  149.979996  150.360001  148.789993  149.320007  149.320007  6366500
# 2023-09-27  149.419998  149.699997  146.630005  147.339996  147.339996  5403700
# 2023-09-28  147.820007  147.979996  145.679993  146.339996  146.339996  6237100
# 2023-09-29  146.539993  146.770004  144.820007  145.860001  145.860001  6675100

# %%
PG['simple_return'] = (PG['Adj Close']/PG['Adj Close'].shift(1))-1
print (PG['simple_return'])
# Out:
# Date
# 1995-01-03         NaN
# 1995-01-04   -0.008016
# 1995-01-05   -0.014142
# 1995-01-06    0.002049
# 1995-01-09   -0.004090
#                 ...
# 2023-09-25   -0.006069
# 2023-09-26   -0.008894
# 2023-09-27   -0.013260
# 2023-09-28   -0.006787
# 2023-09-29   -0.003280
# Name: simple_return, Length: 7237, dtype: float64

# %%
PG['simple_return'].plot(figsize=(8,5))
plt.show()

# %%
avg_returns_d = PG['simple_return'].mean()
avg_returns_d
# Out:
# 0.0005055217830706103

# %%
avg_returns_a = PG['simple_return'].mean() * 250
avg_returns_a
# Out:
# 0.12638044576765256

# %%
print (str(round(avg_returns_a, 5) * 100) + '%')
# Out:
# 12.638%
